# %% [markdown]
# <a href="https://colab.research.google.com/github/recursosdecursos/fp2026/blob/main/docs/Sesion_16_Evaluacion_Final.ipynb" target="_blank" rel="noopener">Abrir en Google Colab</a>

# %% [markdown]
# # Sesión 16: Evaluación final
#
# ## Propósito
# Evaluar la resolución integrada de problemas con funciones, estructuras de datos y persistencia básica.
#
# ## Criterios de evaluación
# - Descompone el problema en funciones o etapas claras.
# - Selecciona correctamente estructuras de datos y persistencia básica.
# - Entrega una solución funcional y legible.
# - Comprueba el programa con casos representativos.

# %% [markdown]
# ## Indicaciones
#
# - Lee cada problema completo antes de escribir código.
# - Diseña al menos un caso de prueba por problema.
# - Mantén nombres de variables claros.
# - Verifica el resultado antes de entregar.

# %% [markdown]
# ## Problema 1: Registro académico básico
#
# Construye un programa con menú que permita registrar estudiantes, guardar la información en archivo y consultar los registros almacenados.
#
# **Entradas esperadas:** opciones de menú, nombre del estudiante y nota
#
# **Salida esperada:** registro actualizado y consulta de datos almacenados

# %%
def mostrar_menu():
    print('1. Registrar estudiante')
    print('2. Mostrar registros')
    print('3. Salir')

# Desarrolla aquí la solución completa

# %% [markdown]
# ## Problema 2: Inventario básico persistente
#
# Desarrolla una solución que permita registrar productos en memoria, guardarlos en archivo y luego recuperar la información para mostrarla ordenada.
#
# **Entradas esperadas:** nombre de producto y precio
#
# **Salida esperada:** listado de productos guardados y recuperados

# %%
productos = []

# Desarrolla aquí la solución completa

# %% [markdown]
# ## Cierre
#
# Antes de entregar, revisa que tu solución funcione con varios casos de prueba y que el código sea legible.
