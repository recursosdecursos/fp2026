# %% [markdown]
# <a href="https://colab.research.google.com/github/recursosdecursos/fp2026/blob/main/docs/Sesion_13_Funciones_Parametros_Retorno_Modularizacion.ipynb" target="_blank" rel="noopener">Abrir en Google Colab</a>

# %% [markdown]
# # Sesión 13: Funciones, parámetros, retorno y modularización
#
# ## Objetivo
# Dividir un problema en partes reutilizables mediante funciones con parámetros y retorno.
#
# ## Resultado esperado
# Programa organizado en funciones claras que resuelvan subproblemas concretos.
#
# ## Dificultad sugerida
# Intermedio
#
# ## Contenidos
# - funciones
# - parámetros
# - return
# - modularización
# - reutilización

# %% [markdown]
# ## Ruta de trabajo
#
# 1. Comprender el problema.
# 2. Identificar entradas, proceso y salidas.
# 3. Diseñar una solución breve antes de programar.
# 4. Probar con casos normales y casos límite.
# 5. Corregir y explicar la lógica aplicada.

# %% [markdown]
# ## Ejemplo guiado
#
# Crearemos una función para calcular el promedio y otra para decidir el resultado final del estudiante.

# %%
def calcular_promedio(n1, n2, n3):
    return (n1 + n2 + n3) / 3

def obtener_resultado(promedio):
    if promedio >= 11:
        return 'Aprobado'
    return 'Desaprobado'

promedio = calcular_promedio(15, 12, 14)
print('Promedio:', promedio)
print('Resultado:', obtener_resultado(promedio))

# %% [markdown]
# ## Práctica intermedia
#
# Integra la técnica principal de la sesión con una estructura de datos o una regla adicional para acercarte a un problema más completo.

# %%
# Resuelve aquí una práctica intermedia
# Integra la técnica principal con una condición o estructura adicional

# %% [markdown]
# ## Reto aplicado
#
# Escribe una función que reciba una lista de números y retorne el mayor valor. Luego úsala en un programa principal.

# %%
def mayor_lista(numeros):
    # Retorna el mayor valor de la lista
    pass

datos = [7, 12, 5, 18, 9]
print(mayor_lista(datos))

# %% [markdown]
# ## Checklist de cierre
#
# - Cada función resuelve una tarea específica.
# - Usé parámetros para evitar repetir código.
# - El valor de retorno fue aprovechado en el programa principal.
# - Probé la función con más de un caso.
