# %% [markdown]
# <a href="https://colab.research.google.com/github/recursosdecursos/fp2026/blob/main/docs/Sesion_06_Repeticion_Definida_For.ipynb" target="_blank" rel="noopener">Abrir en Google Colab</a>

# %% [markdown]
# # Sesión 6: Repetición definida con for
#
# ## Objetivo
# Resolver problemas que requieren repetir una acción un número conocido de veces.
#
# ## Resultado esperado
# Programa que use for, contadores y acumuladores para procesar varios datos.
#
# ## Dificultad sugerida
# Básico - intermedio
#
# ## Contenidos
# - for
# - range
# - contadores
# - acumuladores
# - sumatorias

# %% [markdown]
# ## Ruta de trabajo
#
# 1. Comprender el problema.
# 2. Identificar entradas, proceso y salidas.
# 3. Diseñar una solución breve antes de programar.
# 4. Probar con casos normales y casos límite.
# 5. Corregir y explicar la lógica aplicada.

# %% [markdown]
# ## Ejemplo guiado
#
# Contaremos cuántos estudiantes aprueban dentro de un grupo de cinco registros ingresados por teclado.

# %%
aprobados = 0
for i in range(5):
    nota = float(input(f'Nota {i + 1}: '))
    if nota >= 11:
        aprobados += 1

print('Total de aprobados:', aprobados)

# %% [markdown]
# ## Práctica intermedia
#
# Resuelve un caso con más datos o más validaciones que el ejemplo guiado, manteniendo la misma técnica principal.

# %%
# Resuelve aquí una práctica intermedia
# Agrega más datos o más validaciones al problema

# %% [markdown]
# ## Reto aplicado
#
# Solicita 6 números y muestra la suma total y cuántos son pares.

# %%
suma = 0
pares = 0

for i in range(6):
    numero = int(input(f'Número {i + 1}: '))
    # Completa el procesamiento

print('Suma:', suma)
print('Pares:', pares)

# %% [markdown]
# ## Checklist de cierre
#
# - Usé un contador cuando necesitaba contar casos.
# - Usé un acumulador cuando necesitaba sumar valores.
# - El ciclo repite exactamente el número esperado de veces.
# - Probé la solución con datos pequeños.
