# %% [markdown]
# <a href="https://colab.research.google.com/github/recursosdecursos/fp2026/blob/main/docs/Sesion_09_Busqueda_Secuencial_Ordenacion_Basica.ipynb" target="_blank" rel="noopener">Abrir en Google Colab</a>

# %% [markdown]
# # Sesión 9: Búsqueda secuencial y ordenación básica
#
# ## Objetivo
# Resolver problemas de localización y ordenamiento de datos usando técnicas básicas.
#
# ## Resultado esperado
# Programa que encuentre elementos y ordene listas con una estrategia elemental.
#
# ## Dificultad sugerida
# Básico - intermedio
#
# ## Contenidos
# - búsqueda secuencial
# - comparación de elementos
# - ordenación básica
# - intercambio de valores
# - análisis del proceso

# %% [markdown]
# ## Ruta de trabajo
#
# 1. Comprender el problema.
# 2. Identificar entradas, proceso y salidas.
# 3. Diseñar una solución breve antes de programar.
# 4. Probar con casos normales y casos límite.
# 5. Corregir y explicar la lógica aplicada.

# %% [markdown]
# ## Ejemplo guiado
#
# Buscaremos un valor en una lista y luego aplicaremos una ordenación simple por intercambio.

# %%
datos = [8, 3, 6, 1, 9]
buscado = 6

indice = -1
for i in range(len(datos)):
    if datos[i] == buscado:
        indice = i
        break

print('Índice encontrado:', indice)

for i in range(len(datos)):
    for j in range(i + 1, len(datos)):
        if datos[j] < datos[i]:
            datos[i], datos[j] = datos[j], datos[i]

print('Lista ordenada:', datos)

# %% [markdown]
# ## Práctica intermedia
#
# Resuelve un caso con más datos o más validaciones que el ejemplo guiado, manteniendo la misma técnica principal.

# %%
# Resuelve aquí una práctica intermedia
# Agrega más datos o más validaciones al problema

# %% [markdown]
# ## Reto aplicado
#
# Solicita una lista de 5 enteros, encuentra el mayor y luego ordénala de menor a mayor sin usar sort().

# %%
numeros = []
for i in range(5):
    numeros.append(int(input(f'Número {i + 1}: ')))

# Busca el mayor y ordena la lista sin usar sort()

# %% [markdown]
# ## Checklist de cierre
#
# - Distinguí entre buscar y ordenar.
# - Usé ciclos correctamente para comparar elementos.
# - No utilicé funciones automáticas de ordenación.
# - Probé con listas ya ordenadas y desordenadas.
