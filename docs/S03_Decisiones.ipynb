# %% [markdown]
# <a href="https://colab.research.google.com/github/recursosdecursos/fp2026/blob/main/docs/S03_Decisiones.ipynb" target="_blank" rel="noopener">Abrir en Google Colab</a>

# %% [markdown]
# # Sesión 3: Decisiones simples y compuestas
#
# ## Objetivo
# Resolver problemas que requieren evaluar condiciones simples y compuestas.
#
# ## Resultado esperado
# Programa que tome decisiones correctas según los datos de entrada.
#
# ## Alcance de la sesión
# - Base conceptual: if, if-else, condiciones compuestas, validación básica, casos de prueba.
# - Práctica guiada: mini laboratorio y ejercicios de aplicación progresiva.
# - Aprendizaje autónomo: variaciones de los ejercicios para reforzar la práctica.
# - Evaluación de la sesión: verificación del uso correcto de los conceptos y de la salida esperada.
#
# ## Base conceptual de la sesión
# - if
# - if-else
# - condiciones compuestas
# - validación básica
# - casos de prueba

# %% [markdown]
# **1. If**
# **Concepto**
# Permite ejecutar una acción solo cuando una condición se cumple.
#
# **Elementos o clasificación**
# Decisión simple con una sola condición y una sola acción principal.
#
# **Criterio de uso**
# Se usa cuando una acción depende de una condición. Si la condición es falsa y no existe otra rama, el programa continúa con la siguiente instrucción.
#
# **Ejemplo de aplicación**
# ```python
# if nota >= 11:
#     print("Aprueba")
# ```
#
# **2. If-Else**
# **Concepto**
# Define dos caminos posibles según el resultado de una condición.
#
# **Elementos o clasificación**
# Decisión binaria con camino verdadero y camino falso.
#
# **Criterio de uso**
# Se usa cuando el problema exige escoger entre dos caminos excluyentes. Cada camino debe producir un resultado coherente para el usuario.
#
# **Ejemplo de aplicación**
# ```python
# if edad >= 18:
#     print("Mayor")
# else:
#     print("Menor")
# ```
#
# **3. Condiciones Compuestas**
# **Concepto**
# Usan operadores lógicos para evaluar más de una regla al mismo tiempo.
#
# **Elementos o clasificación**
# Condiciones unidas por and, or y not.
#
# **Criterio de uso**
# Conviene construirlas a partir de condiciones simples ya entendidas. Si una condición se vuelve extensa, debe separarse en variables lógicas con nombres claros.
#
# **Ejemplo de aplicación**
# ```python
# if edad >= 18 and promedio >= 14:
#     print("Beca")
# ```
#
# **4. Validación Básica**
# **Concepto**
# Sirve para comprobar si los datos ingresados tienen sentido antes de continuar.
#
# **Elementos o clasificación**
# Validación de rango, formato y consistencia.
#
# **Criterio de uso**
# La validación protege al algoritmo de datos imposibles o incoherentes antes de realizar cálculos, clasificaciones o salidas finales.
#
# **Ejemplo de aplicación**
# ```python
# if nota < 0 or nota > 20:
#     print("Fuera de rango")
# ```
#
# **5. Casos De Prueba**
# **Concepto**
# Permiten verificar si la solución funciona en situaciones normales, límite y excepcionales.
#
# **Elementos o clasificación**
# Casos normales, límite y excepcionales.
#
# **Criterio de uso**
# Una solución debe probarse con datos normales, valores de frontera y entradas inválidas o poco frecuentes.
#
# **Ejemplo de aplicación**
# Probar con 10.9, 11 y 20 para observar cambios de resultado.
#
# **Síntesis de la sesión**
# Para resolver ejercicios, no basta con escribir instrucciones en Python. Es necesario reconocer los datos, nombrarlos correctamente, elegir operaciones o estructuras de control apropiadas y comprobar el resultado con casos de prueba.
#
# | Aspecto | Pregunta guía |
# |---|---|
# | Entrada | ¿Qué datos necesita recibir el programa? |
# | Proceso | ¿Qué cálculos, decisiones o repeticiones transforman los datos? |
# | Salida | ¿Qué resultado debe mostrarse y con qué formato? |
# | Prueba | ¿Con qué casos se demuestra que la solución funciona? |

# %% [markdown]
# ## Actividad práctica
#
# La sesión se desarrolla con exploración inicial, ejercicios guiados, ejercicios de aplicación y una tarea tipo competencia.

# %% [markdown]
# ### Arquitectura
#
# ```text
# Problema
# |
# Entrada -> Proceso -> Salida
# |
# Código en Python
# ```

# %% [markdown]
# ### Mini laboratorio
#
# Experimenta con decisiones simples y compuestas cambiando los datos de entrada para observar cómo cambia la salida.

# %%
edad = 17
tiene_carne = 'si'

if edad < 18 or tiene_carne == 'si':
    print('Aplica')
else:
    print('No aplica')

# %% [markdown]
# ### Ejercicio 1: Descuento por edad y carné
#
# Determinaremos si una persona accede a un descuento según su edad y si cuenta con carné estudiantil.
#
# **Resolución guiada**
#
# 1. Comprender: explica con una oración completa cuál es el resultado que debe obtener el programa.
# 2. Entradas: enumera cada dato de entrada e indica su tipo de dato esperado.
# 3. Procesos:
# - describe la operación, condición, recorrido o función principal que usarás para resolver el problema
# - ordena las acciones principales antes de escribir el código
# - prepara cómo obtendrás el resultado final antes de mostrarlo
# 4. Salidas: especifica la salida esperada y el formato con que se debe mostrar.
# 5. Pruebas:
# - caso normal: usa datos habituales para comprobar que el resultado esperado se cumpla
# - caso límite: prueba el valor exacto donde cambia la regla principal
# - caso excepcional: revisa qué sucede con una entrada vacía, inválida o fuera de rango
# 6. Código:

# %%
edad = int(input('Edad: '))
tiene_carne = input('¿Tiene carné estudiantil? (si/no): ').strip().lower()

if edad < 18 or tiene_carne == 'si':
    print('Aplica a descuento.')
else:
    print('No aplica a descuento.')

# %% [markdown]
# ### Ejercicio 2: Ingreso a un juego
#
# Solicita la edad y la estatura de una persona. Indica si puede ingresar a un juego que exige ser mayor o medir más de 1.60 m.
#
# **Resolución guiada**
#
# 1. Comprender: el programa debe resolver este problema: Solicita la edad y la estatura de una persona. Indica si puede ingresar a un juego que exige ser mayor o medir más de 1.60 m
# 2. Entradas: escribe las dos entradas requeridas
# 3. Procesos:
# - formula la condición compuesta de ingreso
# - ordena las operaciones o decisiones antes de escribir el código
# - prepara el resultado final que mostrarás al usuario
# 4. Salidas: muestra el resultado solicitado por el enunciado con mensajes claros y ordenados.
# 5. Pruebas:
# - prueba un caso que cumpla y otro que no cumpla
# - caso límite: prueba el valor exacto donde cambia la regla, condición o cálculo principal
# - caso excepcional: revisa qué ocurre con una entrada vacía, inválida o fuera de rango
# 6. Código:

# %%
edad = int(input('Edad: '))
estatura = float(input('Estatura: '))
puede_ingresar = edad >= 18 or estatura > 1.60

print('¿Puede ingresar?:', puede_ingresar)

# %% [markdown]
# ### Ejercicio 3: Aprobación por promedio y asistencia
#
# Pide el promedio final y la asistencia de un estudiante. Determina si aprueba solo si el promedio es al menos 11 y la asistencia supera 70%.
#
# **Resolución guiada**
#
# 1. Comprender: el programa debe resolver este problema: Pide el promedio final y la asistencia de un estudiante. Determina si aprueba solo si el promedio es al menos 11 y la asistencia supera 70%
# 2. Entradas: identifica las entradas y sus tipos
# 3. Procesos:
# - expresa la condición con operador lógico and
# - ordena las operaciones o decisiones antes de escribir el código
# - prepara el resultado final que mostrarás al usuario
# 4. Salidas: muestra el resultado solicitado por el enunciado con mensajes claros y ordenados.
# 5. Pruebas:
# - verifica con un caso que falle por promedio y otro por asistencia
# - caso límite: prueba el valor exacto donde cambia la regla, condición o cálculo principal
# - caso excepcional: revisa qué ocurre con una entrada vacía, inválida o fuera de rango
# 6. Código:

# %%
promedio = float(input('Promedio: '))
asistencia = float(input('Asistencia %: '))
aprueba = promedio >= 11 and asistencia > 70

print('¿Aprueba?:', aprueba)

# %% [markdown]
# ### Ejercicio 4: Validación de nota
#
# Solicita una nota y valida si está dentro del rango permitido de 0 a 20.
#
# **Resolución guiada**
#
# 1. Comprender: una nota solo es válida si cumple el límite inferior y superior.
# 2. Entradas: una nota numérica.
# 3. Procesos:
# - lee la nota con `float()`
# - usa `and` para verificar `nota >= 0` y `nota <= 20`
# - muestra si la nota es válida o inválida
# 4. Salidas: mensaje de validación.
# 5. Pruebas: prueba con `0`, `20`, `21` y `-1`.
# 6. Código:

# %%
nota = float(input('Nota: '))

if nota >= 0 and nota <= 20:
    print('Nota válida')
else:
    print('Nota inválida')

# %% [markdown]
# ### Ejercicio 5: Clasificación de temperatura
#
# Solicita una temperatura y determina si el clima se considera frío, templado o cálido usando decisiones simples y compuestas.
#
# **Resolución guiada**
#
# 1. Comprender: redacta con tus palabras qué debe resolver la tarea.
# 2. Entradas: define qué datos ingresan y el tipo que tendrán.
# 3. Procesos:
# - describe la estrategia, fórmula, condición, estructura o algoritmo que piensas aplicar
# - ordena las acciones principales antes de escribir el código
# - prepara cómo obtendrás el resultado final antes de mostrarlo
# 4. Salidas: indica con claridad qué resultado debe mostrar o registrar la solución.
# 5. Pruebas:
# - caso normal: usa datos habituales para comprobar que la solución funcione
# - caso límite: prueba el valor exacto donde cambia la regla principal
# - caso excepcional: revisa qué ocurre con una entrada vacía, inválida o fuera de rango
# 6. Código:

# %%
temperatura = float(input('Temperatura: '))

if temperatura < 15:
    print('Clima frío')
elif temperatura <= 25:
    print('Clima templado')
else:
    print('Clima cálido')

# %% [markdown]
# ## Aprendizaje autónomo
#
# - Diseña una condición compuesta para ingreso a biblioteca o laboratorio.
# - Evalúa si un estudiante recibe beneficio según promedio y asistencia.
# - Propón dos casos donde una condición con `or` sea más adecuada que una con `and`.

# %% [markdown]
# ## Evaluación de la sesión
#
# Lista de cotejo para revisar el trabajo del estudiante:
#
# - [ ] Identifica la condición que decide la salida del programa.
# - [ ] Usa `if` o `if-else` de acuerdo con el problema.
# - [ ] Escribe condiciones simples o compuestas de forma legible.
# - [ ] Usa operadores lógicos solo cuando son necesarios.
# - [ ] Prueba al menos un caso verdadero y un caso falso.
# - [ ] Muestra una salida clara según la decisión tomada.
