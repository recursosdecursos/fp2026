# %% [markdown]
# <a href="https://colab.research.google.com/github/recursosdecursos/fp2026/blob/main/docs/Sesion_15_Persistencia_Basica_Archivos.ipynb" target="_blank" rel="noopener">Abrir en Google Colab</a>

# %% [markdown]
# # Sesión 15: Persistencia básica de información
#
# ## Objetivo
# Registrar y recuperar información simple usando archivos de texto.
#
# ## Resultado esperado
# Programa que escriba datos en un archivo y luego los lea para mostrarlos o procesarlos.
#
# ## Dificultad sugerida
# Intermedio
#
# ## Contenidos
# - persistencia
# - archivos de texto
# - escritura
# - lectura
# - registro y recuperación

# %% [markdown]
# ## Método o Ruta de trabajo
#
# 1. Comprender el problema: ¿qué se pide?
# 2. Identificar entradas: ¿qué datos necesito?
# 3. Diseñar el proceso: ¿qué operaciones o decisiones realizaré?
# 4. Definir salidas: ¿qué debe mostrar o registrar la solución?
# 5. Diseñar pruebas: ¿con qué casos comprobaré que funciona?
# 6. Escribir, ejecutar y corregir el código.
#
# En cada ejercicio aplicaremos estos pasos antes de programar.

# %% [markdown]
# ## Arquitectura para resolver ejercicios
#
# ```text
# Problema
# |
# Entrada -> Proceso -> Salida
# |
# Código en Python
# ```

# %% [markdown]
# ## Mini laboratorio
#
# Escribe y lee una línea en un archivo de texto para observar la idea básica de persistencia.

# %%
with open('demo.txt', 'w', encoding='utf-8') as archivo:
    archivo.write('hola mundo')

with open('demo.txt', 'r', encoding='utf-8') as archivo:
    print(archivo.read())

# %% [markdown]
# ## Ejercicio 1
#
# Guardaremos nombres en un archivo de texto y luego los recuperaremos para mostrarlos en pantalla.
#
# ## Resolución guiada aplicada
#
# 1. Comprender: explica con una oración completa cuál es el resultado que debe obtener el programa.
# 2. Entradas: enumera cada dato de entrada e indica su tipo de dato esperado.
# 3. Procesos:
# - describe la operación, condición, recorrido o función principal que usarás para resolver el problema
# - ordena las acciones principales antes de escribir el código
# - prepara cómo obtendrás el resultado final antes de mostrarlo
# 4. Salidas: especifica la salida esperada y el formato con que se debe mostrar.
# 5. Pruebas:
# - caso normal: usa datos habituales para comprobar que el resultado esperado se cumpla
# - caso límite: prueba el valor exacto donde cambia la regla principal
# - caso excepcional: revisa qué sucede con una entrada vacía, inválida o fuera de rango
# 6. Código:

# %%
with open('nombres.txt', 'w', encoding='utf-8') as archivo:
    archivo.write('Ana\n')
    archivo.write('Luis\n')

with open('nombres.txt', 'r', encoding='utf-8') as archivo:
    for linea in archivo:
        print(linea.strip())

# %% [markdown]
# ## Ejercicio 2
#
# Guarda tres nombres de estudiantes en un archivo y luego léelos para mostrarlos numerados.
#
# ## Resolución guiada aplicada
#
# 1. Comprender: el programa debe resolver este problema: Guarda tres nombres de estudiantes en un archivo y luego léelos para mostrarlos numerados
# 2. Entradas: separa claramente la parte de escritura y la de lectura
# 3. Procesos:
# - define el nombre del archivo
# - ordena las operaciones o decisiones antes de escribir el código
# - prepara el resultado final que mostrarás al usuario
# 4. Salidas: muestra el resultado solicitado por el enunciado con mensajes claros y ordenados.
# 5. Pruebas:
# - comprueba que cada línea se recupere correctamente
# - caso límite: prueba el valor exacto donde cambia la regla, condición o cálculo principal
# - caso excepcional: revisa qué ocurre con una entrada vacía, inválida o fuera de rango
# 6. Código:

# %%
with open('estudiantes.txt', 'w', encoding='utf-8') as archivo:
    archivo.write('Ana
')
    archivo.write('Luis
')
    archivo.write('Marta
')

with open('estudiantes.txt', 'r', encoding='utf-8') as archivo:
    for indice, linea in enumerate(archivo, start=1):
        print(indice, linea.strip())

# %% [markdown]
# ## Ejercicio 3
#
# Registra productos con su precio en un archivo de texto y luego recupéralos para mostrarlos en pantalla.
#
# ## Resolución guiada aplicada
#
# 1. Comprender: el programa debe resolver este problema: Registra productos con su precio en un archivo de texto y luego recupéralos para mostrarlos en pantalla
# 2. Entradas: define el formato en que guardarás cada producto
# 3. Procesos:
# - separa escritura y lectura
# - ordena las operaciones o decisiones antes de escribir el código
# - prepara el resultado final que mostrarás al usuario
# 4. Salidas: muestra el resultado solicitado por el enunciado con mensajes claros y ordenados.
# 5. Pruebas:
# - verifica que los datos recuperados sean legibles
# - caso límite: prueba el valor exacto donde cambia la regla, condición o cálculo principal
# - caso excepcional: revisa qué ocurre con una entrada vacía, inválida o fuera de rango
# 6. Código:

# %%
with open('productos.txt', 'w', encoding='utf-8') as archivo:
    archivo.write('cuaderno,5.5
')
    archivo.write('lapiz,1.2
')
    archivo.write('mochila,45.0
')

with open('productos.txt', 'r', encoding='utf-8') as archivo:
    for linea in archivo:
        producto, precio = linea.strip().split(',')
        print(producto, '->', precio)

# %% [markdown]
# ## Tarea tipo competencia
#
# Guarda tres productos con su precio en un archivo y luego léelos para mostrarlos en formato de lista.
#
# ## Resolución guiada aplicada
#
# 1. Comprender: redacta con tus palabras qué debe resolver la tarea.
# 2. Entradas: define qué datos ingresan y el tipo que tendrán.
# 3. Procesos:
# - describe la estrategia, fórmula, condición, estructura o algoritmo que piensas aplicar
# - ordena las acciones principales antes de escribir el código
# - prepara cómo obtendrás el resultado final antes de mostrarlo
# 4. Salidas: indica con claridad qué resultado debe mostrar o registrar la solución.
# 5. Pruebas:
# - caso normal: usa datos habituales para comprobar que la solución funcione
# - caso límite: prueba el valor exacto donde cambia la regla principal
# - caso excepcional: revisa qué ocurre con una entrada vacía, inválida o fuera de rango
# 6. Código:

# %%
with open('productos_persistencia.txt', 'w', encoding='utf-8') as archivo:
    archivo.write('cuaderno,5.5\n')
    archivo.write('lapiz,1.2\n')
    archivo.write('mochila,45.0\n')

with open('productos_persistencia.txt', 'r', encoding='utf-8') as archivo:
    for linea in archivo:
        producto, precio = linea.strip().split(',')
        print('- ', producto, ': ', precio, sep='')

# %% [markdown]
# ## Aprendizaje autónomo
#
# - Guarda nombres o productos en un archivo y recupéralos.
# - Diseña un formato simple para registrar datos por línea.
# - Verifica cómo cambia el archivo después de cada escritura.

# %% [markdown]
# ## Checklist de cierre
#
# - Distinguí claramente escritura y lectura de archivos.
# - Usé rutas y nombres de archivo consistentes.
# - Verifiqué que la información guardada pueda recuperarse.
# - El archivo contiene datos legibles y ordenados.
