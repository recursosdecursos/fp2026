# %% [markdown]
# <a href="https://colab.research.google.com/github/recursosdecursos/fp2026/blob/main/docs/Sesion_14_Integracion_Funciones_Colecciones_Menus.ipynb" target="_blank" rel="noopener">Abrir en Google Colab</a>

# %% [markdown]
# # Sesión 14: Integración de funciones, colecciones y menús
#
# ## Objetivo
# Construir un programa que integre funciones, estructuras de datos y un menú sencillo de opciones.
#
# ## Resultado esperado
# Programa modular con menú, registro y consulta de información en memoria.
#
# ## Dificultad sugerida
# Intermedio
#
# ## Contenidos
# - menús
# - integración de funciones
# - listas o diccionarios
# - flujo del programa
# - organización de opciones

# %% [markdown]
# ## Método o Ruta de trabajo
#
# 1. Comprender el problema: ¿qué se pide?
# 2. Identificar entradas: ¿qué datos necesito?
# 3. Diseñar el proceso: ¿qué operaciones o decisiones realizaré?
# 4. Definir salidas: ¿qué debe mostrar o registrar la solución?
# 5. Diseñar pruebas: ¿con qué casos comprobaré que funciona?
# 6. Escribir, ejecutar y corregir el código.
#
# En cada ejercicio aplicaremos estos pasos antes de programar.

# %% [markdown]
# ## Arquitectura para resolver ejercicios
#
# ```text
# Problema
# |
# Entrada -> Proceso -> Salida
# |
# Código en Python
# ```

# %% [markdown]
# ## Mini laboratorio
#
# Separa una tarea breve en función y flujo principal para reconocer cómo se integra un programa modular.

# %%
def mostrar_menu():
    print('1. Continuar')
    print('2. Salir')

mostrar_menu()

# %% [markdown]
# ## Ejercicio 1
#
# Construiremos un menú básico para registrar y mostrar nombres en una lista.
#
# ## Resolución guiada aplicada
#
# 1. Comprender: explica con una oración completa cuál es el resultado que debe obtener el programa.
# 2. Entradas: enumera cada dato de entrada e indica su tipo de dato esperado.
# 3. Procesos:
# - describe la operación, condición, recorrido o función principal que usarás para resolver el problema
# - ordena las acciones principales antes de escribir el código
# - prepara cómo obtendrás el resultado final antes de mostrarlo
# 4. Salidas: especifica la salida esperada y el formato con que se debe mostrar.
# 5. Pruebas:
# - caso normal: usa datos habituales para comprobar que el resultado esperado se cumpla
# - caso límite: prueba el valor exacto donde cambia la regla principal
# - caso excepcional: revisa qué sucede con una entrada vacía, inválida o fuera de rango
# 6. Código:

# %%
def mostrar_menu():
    print('1. Agregar nombre')
    print('2. Mostrar nombres')
    print('3. Salir')

nombres = []
opcion = ''

while opcion != '3':
    mostrar_menu()
    opcion = input('Opción: ')
    if opcion == '1':
        nombres.append(input('Nombre: '))
    elif opcion == '2':
        print(nombres)

# %% [markdown]
# ## Ejercicio 2
#
# Amplía el menú para permitir eliminar un nombre registrado de la lista.
#
# ## Resolución guiada aplicada
#
# 1. Comprender: el programa debe resolver este problema: Amplía el menú para permitir eliminar un nombre registrado de la lista
# 2. Entradas: define la nueva opción del menú
# 3. Procesos:
# - decide qué sucede si el nombre no existe
# - ordena las operaciones o decisiones antes de escribir el código
# - prepara el resultado final que mostrarás al usuario
# 4. Salidas: muestra el resultado solicitado por el enunciado con mensajes claros y ordenados.
# 5. Pruebas:
# - prueba el flujo completo con agregar, mostrar y eliminar
# - caso límite: prueba el valor exacto donde cambia la regla, condición o cálculo principal
# - caso excepcional: revisa qué ocurre con una entrada vacía, inválida o fuera de rango
# 6. Código:

# %%
def mostrar_menu():
    print('1. Agregar nombre')
    print('2. Mostrar nombres')
    print('3. Eliminar nombre')
    print('4. Salir')

nombres = []
opcion = ''

while opcion != '4':
    mostrar_menu()
    opcion = input('Opción: ')
    if opcion == '1':
        nombres.append(input('Nombre: '))
    elif opcion == '2':
        print(nombres)
    elif opcion == '3':
        nombre = input('Nombre a eliminar: ')
        if nombre in nombres:
            nombres.remove(nombre)
            print('Nombre eliminado')
        else:
            print('Nombre no encontrado')

# %% [markdown]
# ## Ejercicio 3
#
# Construye un menú para registrar cursos y consultar si un curso ya fue ingresado.
#
# ## Resolución guiada aplicada
#
# 1. Comprender: el programa debe resolver este problema: Construye un menú para registrar cursos y consultar si un curso ya fue ingresado
# 2. Entradas: define la estructura de datos a utilizar
# 3. Procesos:
# - separa en funciones registrar y consultar
# - ordena las operaciones o decisiones antes de escribir el código
# - prepara el resultado final que mostrarás al usuario
# 4. Salidas: muestra el resultado solicitado por el enunciado con mensajes claros y ordenados.
# 5. Pruebas:
# - verifica el programa con varias opciones seguidas
# - caso límite: prueba el valor exacto donde cambia la regla, condición o cálculo principal
# - caso excepcional: revisa qué ocurre con una entrada vacía, inválida o fuera de rango
# 6. Código:

# %%
def mostrar_menu():
    print('1. Registrar curso')
    print('2. Consultar curso')
    print('3. Salir')

cursos = []
opcion = ''

while opcion != '3':
    mostrar_menu()
    opcion = input('Opción: ')
    if opcion == '1':
        cursos.append(input('Curso: '))
    elif opcion == '2':
        curso = input('Curso a consultar: ')
        print('Registrado:', curso in cursos)

# %% [markdown]
# ## Tarea tipo competencia
#
# Crea un menú para registrar productos y consultar su precio usando un diccionario.
#
# ## Resolución guiada aplicada
#
# 1. Comprender: redacta con tus palabras qué debe resolver la tarea.
# 2. Entradas: define qué datos ingresan y el tipo que tendrán.
# 3. Procesos:
# - describe la estrategia, fórmula, condición, estructura o algoritmo que piensas aplicar
# - ordena las acciones principales antes de escribir el código
# - prepara cómo obtendrás el resultado final antes de mostrarlo
# 4. Salidas: indica con claridad qué resultado debe mostrar o registrar la solución.
# 5. Pruebas:
# - caso normal: usa datos habituales para comprobar que la solución funcione
# - caso límite: prueba el valor exacto donde cambia la regla principal
# - caso excepcional: revisa qué ocurre con una entrada vacía, inválida o fuera de rango
# 6. Código:

# %%
def mostrar_menu():
    print('1. Registrar producto')
    print('2. Consultar producto')
    print('3. Salir')

productos = {}
opcion = ''

while opcion != '3':
    mostrar_menu()
    opcion = input('Opción: ')
    if opcion == '1':
        nombre = input('Producto: ')
        precio = float(input('Precio: '))
        productos[nombre] = precio
    elif opcion == '2':
        nombre = input('Producto a consultar: ')
        if nombre in productos:
            print('Precio:', productos[nombre])
        else:
            print('Producto no encontrado')

# %% [markdown]
# ## Aprendizaje autónomo
#
# - Amplía un menú con una opción nueva de consulta o eliminación.
# - Separa en funciones el registro y la visualización de datos.
# - Prueba varias secuencias de opciones para validar el flujo del programa.

# %% [markdown]
# ## Checklist de cierre
#
# - El menú organiza claramente las opciones del programa.
# - Separé tareas del flujo principal en funciones.
# - La estructura de datos elegida responde al problema.
# - El programa puede ejecutarse varias veces sin romperse.
