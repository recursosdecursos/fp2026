# %% [markdown]
# <a href="https://colab.research.google.com/github/recursosdecursos/fp2026/blob/main/docs/Sesion_05_Evaluacion_1.ipynb" target="_blank" rel="noopener">Abrir en Google Colab</a>

# %% [markdown]
# # Sesión 5: Evaluación 1
#
# ## Propósito
# Evaluar la resolución de problemas secuenciales y condicionales con validación básica.
#
# ## Criterios de evaluación
# - Identifica correctamente entradas, proceso y salida.
# - Usa operadores y decisiones de manera coherente.
# - Presenta salidas claras y comprobables.
# - Prueba la solución con casos distintos.

# %% [markdown]
# ## Indicaciones
#
# - Lee cada problema completo antes de escribir código.
# - Diseña al menos un caso de prueba por problema.
# - Mantén nombres de variables claros.
# - Verifica el resultado antes de entregar.

# %% [markdown]
# ## Problema 1: Control de consumo eléctrico
#
# Lee el consumo mensual en kWh y calcula el pago aplicando una tarifa base y un recargo si supera un umbral definido.
#
# **Entradas esperadas:** consumo mensual y tarifa base
#
# **Salida esperada:** monto total a pagar y mensaje de observación

# %%
consumo = float(input('Consumo kWh: '))
tarifa = float(input('Tarifa base: '))

# Desarrolla aquí la solución

# %% [markdown]
# ## Problema 2: Clasificación de postulantes
#
# Solicita la edad y el puntaje de un postulante. Clasifica si pasa directo, pasa con observación o no pasa según reglas establecidas.
#
# **Entradas esperadas:** edad y puntaje
#
# **Salida esperada:** clasificación final del postulante

# %%
edad = int(input('Edad: '))
puntaje = float(input('Puntaje: '))

# Desarrolla aquí la solución

# %% [markdown]
# ## Cierre
#
# Antes de entregar, revisa que tu solución funcione con varios casos de prueba y que el código sea legible.
