# %% [markdown]
# <a href="https://colab.research.google.com/github/recursosdecursos/fp2026/blob/main/docs/Sesion_01_Pensamiento_Algoritmico_Variables_Tipos_Datos.ipynb" target="_blank" rel="noopener">Abrir en Google Colab</a>

# %% [markdown]
# # Sesión 1: Pensamiento algorítmico, variables y tipos de datos
#
# ## Objetivo
# Comprender la lógica de entrada, proceso y salida, y representar información con variables y tipos de datos básicos.
#
# ## Resultado esperado
# Programa que capture datos de una persona y los muestre de manera clara y ordenada.
#
# ## Dificultad sugerida
# Básico
#
# ## Contenidos
# - algoritmos
# - entrada, proceso y salida
# - variables
# - tipos de datos
# - salida formateada

# %% [markdown]
# ## Ruta de trabajo
#
# 1. Comprender el problema.
# 2. Identificar entradas, proceso y salidas.
# 3. Diseñar una solución breve antes de programar.
# 4. Probar con casos normales y casos límite.
# 5. Corregir y explicar la lógica aplicada.

# %% [markdown]
# ## Ejemplo guiado
#
# Construiremos un programa que solicite nombre, edad y carrera de un estudiante y luego muestre una ficha resumida.

# %%
nombre = input('Nombre: ')
edad = int(input('Edad: '))
carrera = input('Carrera: ')

print('--- Ficha del estudiante ---')
print('Nombre:', nombre)
print('Edad:', edad)
print('Carrera:', carrera)
print('¿Es mayor de edad?:', edad >= 18)

# %% [markdown]
# ## Práctica intermedia
#
# Resuelve una variante cercana del ejemplo guiado, cambiando los datos de entrada y verificando que la lógica siga siendo correcta.

# %%
# Escribe aquí una variante intermedia del ejemplo guiado
# Cambia entradas o condiciones y comprueba el resultado

# %% [markdown]
# ## Reto aplicado
#
# Solicita el nombre de un producto, su precio y la cantidad comprada. Luego muestra un resumen con el costo total.

# %%
producto = input('Producto: ')
precio = float(input('Precio: '))
cantidad = int(input('Cantidad: '))

# Calcula y muestra el resumen de compra

# %% [markdown]
# ## Checklist de cierre
#
# - Identifiqué las entradas antes de programar.
# - Usé variables con nombres claros.
# - Elegí tipos de datos adecuados.
# - Probé al menos dos entradas diferentes.
