# %% [markdown]
# [Abrir en Google Colab](https://colab.research.google.com/github/recursosdecursos/fp2026/blob/main/docs/Sesion_06_Evaluacion_Unidad_1.ipynb){ target="_blank" rel="noopener" }

# %% [markdown]
# # Sesión 6: Evaluación de Unidad 1
#
# ## Objetivo
# Demostrar dominio de entrada, proceso, salida, variables, operadores y condicionales.
#
# ## Resultado esperado
# Programa individual que resuelva un problema completo.
#
# ## Tiempo estimado
# 120 minutos de desarrollo y 30 minutos de revisión.
#
# ## Estructura de la sesión
# - Objetivo y resultado esperado.
# - Mini laboratorio.
# - Ejercicios resueltos.
# - Tarea tipo competencia.
# - Checklist de cierre.

# %% [markdown]
# ## Método de resolución de problemas: 5 pasos
#
# 1. Comprender el problema: ¿qué se pide?
# 2. Identificar entradas: ¿qué datos necesito?
# 3. Diseñar el proceso: ¿qué operaciones o decisiones haré?
# 4. Definir salidas y pruebas: ¿qué debe mostrar y con qué casos lo comprobaré?
# 5. Escribir, ejecutar y corregir el código.
#
# Antes de escribir código, completa manualmente estos pasos.

# %% [markdown]
# # Evaluación: Asistente de notas
#
# ## Problema
# Crear un programa que ayude a revisar el rendimiento de un estudiante.
#
# ## Entrada
# nombre, nota1, nota2 y nota3.
#
# ## Proceso
# Validar notas, calcular promedio, determinar estado y clasificar resultado.
#
# ## Salida esperada
# nombre, promedio, aprobado/desaprobado y clasificación.
#
# ## Restricciones
# - Si una nota está fuera de 0 a 20, mostrar Datos inválidos.
# - No calcular promedio si los datos son inválidos.
# - Usar condicionales.
#
# ## Plan antes de programar
#
# Antes de escribir código para **Asistente de notas**, completa:
#
# 1. Problema: explica en una frase qué debe resolver.
# 2. Entradas: escribe los nombres de las variables que pedirás.
# 3. Proceso: anota la fórmula, condición, bucle o estructura principal.
# 4. Salidas y pruebas: define los mensajes finales y dos casos de prueba.
# 5. Código: implementa por partes y ejecuta cada avance.

# %%
# Escribe aquí tu solución de evaluación

# %% [markdown]
# ## Casos de prueba sugeridos
#
# | Caso | Datos | Resultado esperado |
# |---|---|---|
# | Normal aprobado | 15, 16, 17 | Aprobado |
# | Límite aprobado | 11, 11, 11 | Aprobado |
# | Desaprobado | 8, 10, 12 | Desaprobado |
# | Inválido | 21, 15, 16 | Datos inválidos |

# %% [markdown]
# ## Checklist de la sesión
#
# - [ ] Entrada de datos correcta.
# - [ ] Conversión numérica correcta.
# - [ ] Validación de rango.
# - [ ] Cálculo del promedio.
# - [ ] Salida clara y ordenada.
