# %% [markdown]
# [Abrir en Google Colab](https://colab.research.google.com/github/recursosdecursos/fp2026/blob/main/docs/Sesion_11_Integracion_Bucles_Listas_Funciones.ipynb){ target="_blank" rel="noopener" }

# %% [markdown]
# # Sesión 11: Integración de Bucles, Listas y Funciones
#
# ## Objetivo
# Integrar estructuras repetitivas, listas y funciones en un programa completo.
#
# ## Resultado esperado
# Programa con menú interactivo para registrar, consultar y procesar datos.
#
# ## Tiempo estimado
# 120 minutos.
#
# ## Estructura de la sesión
# - Objetivo y resultado esperado.
# - Mini laboratorio.
# - Ejercicios resueltos.
# - Tarea tipo competencia.
# - Checklist de cierre.

# %% [markdown]
# ## Método de resolución de problemas: 5 pasos
#
# 1. Comprender el problema: ¿qué se pide?
# 2. Identificar entradas: ¿qué datos necesito?
# 3. Diseñar el proceso: ¿qué operaciones o decisiones haré?
# 4. Definir salidas y pruebas: ¿qué debe mostrar y con qué casos lo comprobaré?
# 5. Escribir, ejecutar y corregir el código.
#
# En cada ejercicio usaremos estos pasos antes de programar.

# %% [markdown]
# # Ejercicio 1: Registro de notas con funciones
#
# ## Resolución guiada aplicada
#
# 1. Comprender: un registro de notas combina menú, lista y cálculo; las funciones ayudan a ordenar el programa.
# 2. Entradas: opciones de menú y notas.
# 3. Proceso: guardar notas en lista y usar función para promedio.
# 4. Salida y pruebas: notas registradas y promedio. Prueba con: mostrar sin notas, registrar dos notas, calcular promedio y salir.
# 5. Código: recién ahora revisa o escribe la celda de Python.

# %%
def calcular_promedio(notas):
    suma = 0
    for nota in notas:
        suma = suma + nota
    return suma / len(notas)

notas = []
opcion = ""

while opcion != "4":
    print("1. Registrar nota")
    print("2. Mostrar notas")
    print("3. Calcular promedio")
    print("4. Salir")
    opcion = input("Opción: ")

    if opcion == "1":
        notas.append(float(input("Nota: ")))
    elif opcion == "2":
        print("Notas:", notas)
    elif opcion == "3":
        if len(notas) > 0:
            print("Promedio:", calcular_promedio(notas))
        else:
            print("No hay notas registradas")
    elif opcion == "4":
        print("Fin")
    else:
        print("Opción inválida")

# %% [markdown]
# # Ejercicio 2: Lista de compras modular
#
# ## Resolución guiada aplicada
#
# 1. Comprender: una lista de compras necesita guardar productos y calcular total sin mezclar todo en un solo bloque.
# 2. Entradas: productos y precios.
# 3. Proceso: guardar diccionarios en una lista y calcular total con función.
# 4. Salida y pruebas: productos y total. Prueba con: sin productos; luego dos productos.
# 5. Código: recién ahora revisa o escribe la celda de Python.

# %%
def calcular_total(productos):
    total = 0
    for producto in productos:
        total = total + producto["precio"]
    return total

productos = []
opcion = ""

while opcion != "3":
    print("1. Agregar producto")
    print("2. Mostrar total")
    print("3. Salir")
    opcion = input("Opción: ")

    if opcion == "1":
        nombre = input("Producto: ")
        precio = float(input("Precio: "))
        productos.append({"nombre": nombre, "precio": precio})
    elif opcion == "2":
        print("Productos:", productos)
        print("Total:", calcular_total(productos))
    elif opcion == "3":
        print("Fin")
    else:
        print("Opción inválida")

# %% [markdown]
# # Tarea 1: Ranking de puntajes
#
# ## Problema
# Crear un programa con menú para registrar jugadores y puntajes.
#
# ## Restricciones
# Usa `while`, lista de diccionarios y funciones para calcular promedio y mayor.
#
# ## Plan antes de programar
#
# Antes de escribir código para **Ranking de puntajes**, completa:
#
# 1. Problema: explica en una frase qué debe resolver.
# 2. Entradas: escribe los nombres de las variables que pedirás.
# 3. Proceso: anota la fórmula, condición, bucle o estructura principal.
# 4. Salidas y pruebas: define los mensajes finales y dos casos de prueba.
# 5. Código: implementa por partes y ejecuta cada avance.

# %%
# Escribe aquí tu solución

# %% [markdown]
# ## Checklist de la sesión
#
# - [ ] Uso menú con while.
# - [ ] Guardo datos en listas.
# - [ ] Uso funciones.
# - [ ] Valido opciones del menú.
# - [ ] Pruebo registrar, consultar y salir.
