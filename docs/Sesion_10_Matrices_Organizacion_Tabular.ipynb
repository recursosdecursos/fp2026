# %% [markdown]
# <a href="https://colab.research.google.com/github/recursosdecursos/fp2026/blob/main/docs/Sesion_10_Matrices_Organizacion_Tabular.ipynb" target="_blank" rel="noopener">Abrir en Google Colab</a>

# %% [markdown]
# # Sesión 10: Matrices y organización tabular de información
#
# ## Objetivo
# Representar y procesar datos organizados en filas y columnas.
#
# ## Resultado esperado
# Programa que recorra una matriz y obtenga resúmenes por filas o columnas.
#
# ## Dificultad sugerida
# Intermedio
#
# ## Contenidos
# - matrices
# - filas
# - columnas
# - recorrido bidimensional
# - consulta y actualización

# %% [markdown]
# ## Ruta de trabajo
#
# 1. Comprender el problema.
# 2. Identificar entradas, proceso y salidas.
# 3. Diseñar una solución breve antes de programar.
# 4. Probar con casos normales y casos límite.
# 5. Corregir y explicar la lógica aplicada.

# %% [markdown]
# ## Ejemplo guiado
#
# Calcularemos el total de asistencia por estudiante usando una matriz simple de 0 y 1.

# %%
asistencia = [
    [1, 1, 0],
    [1, 0, 1],
    [1, 1, 1]
]

for fila in range(len(asistencia)):
    total = 0
    for columna in range(len(asistencia[fila])):
        total += asistencia[fila][columna]
    print('Estudiante', fila + 1, ':', total, 'asistencias')

# %% [markdown]
# ## Práctica intermedia
#
# Integra la técnica principal de la sesión con una estructura de datos o una regla adicional para acercarte a un problema más completo.

# %%
# Resuelve aquí una práctica intermedia
# Integra la técnica principal con una condición o estructura adicional

# %% [markdown]
# ## Reto aplicado
#
# Dada una tabla de ventas por día y producto, calcula el total por fila y el total general.

# %%
ventas = [
    [12, 15, 10],
    [8, 11, 9],
    [14, 7, 13]
]

# Calcula totales por fila y total general

# %% [markdown]
# ## Checklist de cierre
#
# - Identifiqué filas y columnas correctamente.
# - Usé ciclos anidados cuando fue necesario.
# - La consulta de posiciones fue clara y precisa.
# - Probé con matrices pequeñas antes de cerrar.
