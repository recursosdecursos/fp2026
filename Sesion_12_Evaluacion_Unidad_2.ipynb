# %% [markdown]
# # Sesión 12: Evaluación de Unidad 2
#
# ## Objetivo
# Demostrar dominio de bucles, listas, estructuras simples y funciones mediante un programa integrador.
#
# ## Resultado esperado
# Programa integrador en Python.
#
# ## Tiempo estimado
# 120 minutos de desarrollo y 30 minutos de revisión.
#
# ## Estructura de la sesión
# - Objetivo y resultado esperado.
# - Mini laboratorio.
# - Ejercicios resueltos.
# - Tarea tipo competencia.
# - Checklist de cierre.

# %% [markdown]
# ## Método de resolución de problemas: 5 pasos
#
# 1. Comprender el problema: ¿qué se pide?
# 2. Identificar entradas: ¿qué datos necesito?
# 3. Diseñar el proceso: ¿qué operaciones o decisiones haré?
# 4. Definir salidas y pruebas: ¿qué debe mostrar y con qué casos lo comprobaré?
# 5. Escribir, ejecutar y corregir el código.
#
# Antes de escribir código, completa mentalmente estos pasos.

# %% [markdown]
# # Evaluación: Registro de notas
#
# ## Problema
# Crear un sistema simple para registrar notas de estudiantes.
#
# ## Entrada
# nombres de estudiantes, notas y opciones de menú.
#
# ## Proceso
# Registrar datos, guardarlos en una estructura, calcular promedio general, nota mayor y nota menor.
#
# ## Salida esperada
# Lista de estudiantes registrados, promedio general, nota mayor, nota menor y clasificación.
#
# ## Requisitos mínimos
# - Menú con `while`.
# - Lista para guardar datos.
# - Diccionarios para organizar cada estudiante.
# - Funciones para calcular promedio, mayor y menor.
# - Validación de notas entre 0 y 20.

# %%
# Escribe aquí tu solución de evaluación

# %% [markdown]
# ## Casos de prueba sugeridos
#
# | Caso | Acción | Resultado esperado |
# |---|---|---|
# | Registrar estudiante válido | Ana, 16 | Se agrega a la lista |
# | Nota inválida | Luis, 25 | Mensaje de error |
# | Mostrar sin datos | Elegir reporte sin registrar | Mensaje claro |
# | Varios estudiantes | 3 registros | Promedio, mayor y menor correctos |
# | Salir | Opción salir | Termina el programa |

# %% [markdown]
# ## Checklist de la sesión
#
# - [ ] Uso menú con while.
# - [ ] Uso listas y diccionarios.
# - [ ] Uso funciones con parámetros y retorno.
# - [ ] Valido notas.
# - [ ] Calculo promedio, mayor y menor.
# - [ ] Muestro resultados claros.
