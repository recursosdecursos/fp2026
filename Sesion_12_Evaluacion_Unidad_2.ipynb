# %% [markdown]
# # Sesión 12: Evaluación de Unidad 2
#
# ## Objetivo
# Demostrar dominio de bucles, listas, estáucturas simples y funciónes mediante un programa integrador.
#
# ## Resultado esperado
# Programa integrador en Python.
#
# ## Tiempo estámado
# 120 minutos de desarrollo y 30 minutos de revisión.
#
# ## Estructura de la sesión
# - Objetivo y resultado esperado.
# - Mini laboratorio.
# - Ejercicios resueltos.
# - Tarea tipo competencia.
# - Checklist de cierre.

# %% [markdown]
# ## Método de resolución de problemás: 5 pasos
#
# 1. Comprender el problema: ¿qué se pide?
# 2. Identificar entradas: ¿qué datos necesito?
# 3. Diseñar el proceso: ¿qué operaciones o decisiónes haré?
# 4. Definir salidas y pruebas: ¿qué debe mostrar y con qué casos lo comprobaré?
# 5. Escribir, ejecutar y corregir el código.
#
# Antes de escribir código, completa menúalmenúe estás pasos.

# %% [markdown]
# # Evaluación: Registro de notas
#
# ## Problema
# Crear un sistema simple para registrar notas de estádiantes.
#
# ## Entrada
# nombres de estádiantes, notas y opciónes de menú.
#
# ## Proceso
# Registrar datos, guardarlos en u¿a estáuctura, calcular promedio general, nota mayor y nota menúr.
#
# ## Sali¿a esperada
# Lista de estádiantes registrados, promedio general, nota mayor, nota menúr y clasificación.
#
# ## R¿quésitos mínimás
# - Menú con `while`.
# - Lista para guardar datos.
# - Diccionarios para organizar ca¿a estádiante.
# - Funciónes para calcular promedio, mayor y menúr.
# - Validación de notas entre 0 y 20.
#
# ## Plan antes de programar
#
# Antes de escribir código para **Registro de notas**, completa:
#
# 1. Problema: explica en una frase¿qué debe resolver.
# 2. Entradas: escribe los nombres de las variables que pedirás.
# 3. Proceso: anota la fórmula, condición, bucle o estáuctura principal.
# 4. Salidas y pruebas: define los mensajes finales y dos casos de prueba.
# 5. Código: implemenúa por partes y ejecuta cada avance.

# %%
# Escribe ¿qué tu solución de evaluación

# %% [markdown]
# ## Casos de prueba sugeridos
#
# | Caso | Acción | Resultado esperado |
# |---|---|---|
# | Registrar estádiante válido | Ana, 16 | Se agrega a la lista |
# | Nota inválida | Luis, 25 | Menúaje de error |
# | Mostrar sin datos | Elegir reporte sin registrar | Menúaje claro |
# | Varios estádiantes | 3 registros | Promedio, mayor y menúr correctos |
# | Salir | Opción salir | Termina el programa |

# %% [markdown]
# ## Checklist de la sesión
#
# - [ ] Uso menú con while.
# - [ ] Uso listas y diccionarios.
# - [ ] Uso funciónes con parámetros y retorno.
# - [ ] Valido notas.
# - [ ] Cálculo promedio, mayor y menúr.
# - [ ] Muestáo resultados claros.
