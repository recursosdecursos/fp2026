# %% [markdown]
# # Sesión 5: Integración de Fundamentos
#
# ## Objetivo
# Integrar arquitectura, entradas, salidas, variables, operadores y decisiones en problemas completos.
#
# ## Producto esperado
# Al terminar, tendrás programas completos que resuelven casos escolares y comerciales simples.
#
# ## Stack / Herramientas
# - Google Colab o Jupyter Notebook.
# - Python.
# - `input()`, `print()`, operadores y condicionales.
#
# ## Tiempo estimado
# 100 a 120 minutos.
#
# ## Partes que aprenderemos
# - Dividir problemas en partes.
# - Combinar cálculos y decisiones.
# - Validar datos.
# - Probar diferentes escenarios.
#
# ## Cómo trabajar esta sesión
# 1. Escribe la arquitectura del problema.
# 2. Programa las entradas.
# 3. Programa los cálculos.
# 4. Agrega decisiones.
# 5. Prueba casos normales y casos límite.
#
# ## Evaluación rápida
# - Mi programa tiene entradas claras.
# - Mi proceso calcula correctamente.
# - Mis decisiones cubren varios casos.
# - Mi salida se entiende.

# %% [markdown]
# # Ejercicio 1: Promedio con clasificación
#
# ## 1. Problema
# Calcular el promedio de tres notas y clasificar el resultado.
#
# ## 2. Entrada
# - nota1
# - nota2
# - nota3
#
# ## 3. Proceso
# - Calcular promedio.
# - Clasificar según el promedio.
#
# ## 4. Salida
# - Mostrar promedio y clasificación.
#
# ## 5. Código en Python

# %%
nota1 = float(input("Nota 1: "))
nota2 = float(input("Nota 2: "))
nota3 = float(input("Nota 3: "))

promedio = (nota1 + nota2 + nota3) / 3
print("Promedio:", promedio)

if promedio >= 18:
    print("Excelente")
elif promedio >= 14:
    print("Bueno")
elif promedio >= 11:
    print("Regular")
else:
    print("Necesita mejorar")

# %% [markdown]
# # Ejercicio 2: Boleta con descuento
#
# ## 1. Problema
# Calcular el total de una compra y aplicar descuento si corresponde.
#
# ## 2. Entrada
# - precio
# - cantidad
#
# ## 3. Proceso
# - Calcular subtotal.
# - Si subtotal >= 100, aplicar 10% de descuento.
# - Calcular total.
#
# ## 4. Salida
# - Mostrar subtotal, descuento y total.
#
# ## 5. Código en Python

# %%
precio = float(input("Precio: "))
cantidad = int(input("Cantidad: "))

subtotal = precio * cantidad

if subtotal >= 100:
    descuento = subtotal * 0.10
else:
    descuento = 0

total = subtotal - descuento

print("Subtotal:", subtotal)
print("Descuento:", descuento)
print("Total:", total)

# %% [markdown]
# # Tarea 1: Asistente de notas
#
# Esta tarea tiene formato de competencia.
#
# ## Problema
# Leer nombre y tres notas. Mostrar promedio y si aprobó o desaprobó.
#
# ## Entrada
# Nombre del estudiante y tres notas.
#
# ## Salida
# Mostrar nombre, promedio y resultado.
#
# ## Restricciones
# - 0 <= nota <= 20
# - Las notas pueden tener decimales.
#
# ## Ejemplo
# Entrada:
# ```text
# Luis
# 14
# 15
# 16
# ```
#
# Salida:
# ```text
# Estudiante: Luis
# Promedio: 15.0
# Resultado: Aprobó
# ```
#
# ## Tu código

# %%
# Escribe aquí tu solución

# %% [markdown]
# ## Checklist de la sesión
#
# - Divido el problema en entrada, proceso y salida.
# - Uso variables y operadores.
# - Uso decisiones.
# - Pruebo al menos tres casos.
# - La salida es clara.
#
# ## Cierre
# Esta sesión cierra los fundamentos iniciales. Ya puedes resolver problemas secuenciales y con decisiones.
