# %% [markdown]
# # Sesión 4: Decisiónes Inteligentes Anidadas y Múltiples
#
# ## Objetivo
# Resolver problemás con varios caminos usando condiciónales anidados y múltiples.
#
# ## Resultado esperado
# Programás¿qué clasif¿quén datos y resuelvan situaciones con más de dos caminos.
#
# ## Tiempo estámado
# 90 minutos.
#
# ## Estructura de la sesión
# - Objetivo y resultado esperado.
# - Mini laboratorio.
# - Ejercicios resueltos.
# - Tarea tipo competencia.
# - Checklist de cierre.

# %% [markdown]
# ## Método de resolución de problemás: 5 pasos
#
# 1. Comprender el problema: ¿qué se pide?
# 2. Identificar entradas: ¿qué datos necesito?
# 3. Diseñar el proceso: ¿qué operaciones o decisiónes haré?
# 4. Definir salidas y pruebas: ¿qué debe mostrar y con qué casos lo comprobaré?
# 5. Escribir, ejecutar y corregir el código.
#
# En cada ejercicio usarámás estás pasos antes de programar.

# %% [markdown]
# ## Mini laboratorio: orden de condiciónes

# %%
promedio = float(input("Promedio: "))

if promedio >= 18:
    print("Logro destácado")
elif promedio >= 14:
    print("Logro esperado")
elif promedio >= 11:
    print("En proceso")
else:
    print("En inicio")

# %% [markdown]
# # Ejercicio 1: Clasificar una nota
#
# ## Resolución guiada aplicada
#
# 1. Comprender: no basta con saber si aprueba;¿quéremás ubicar la nota en una categoría de desempeño.
# 2. Entradas: `nota`.
# 3. Proceso: primero válidar rango; luego clasificar por tramás.
# 4. Salida y pruebas: categoría de logro o mensaje de nota inválida. Prueba con: `19`, `15`, `11`, `8` y `25`.
# 5. Código: recién ahora revisa o escribe la celda de Python.

# %%
nota = float(input("Ingrese la nota: "))

if nota < 0 or nota > 20:
    print("Nota inválida")
elif nota >= 18:
    print("Logro destácado")
elif nota >= 14:
    print("Logro esperado")
elif nota >= 11:
    print("En proceso")
else:
    print("En inicio")

# %% [markdown]
# # Ejercicio 2: Descuento por compra
#
# ## Resolución guiada aplicada
#
# 1. Comprender: una tienda aplica descuentos distintos según el monto comprado; el programa debe elegir el descuento correcto.
# 2. Entradas: `monto`.
# 3. Proceso: elegir porcentaje de descuento según el rango del monto.
# 4. Salida y pruebas: descuento y total a pagar. Prueba con: `40`, `80`, `150` y `250`.
# 5. Código: recién ahora revisa o escribe la celda de Python.

# %%
monto = float(input("Monto de compra: "))

if monto >= 200:
    descuento = monto * 0.15
elif monto >= 100:
    descuento = monto * 0.10
elif monto >= 50:
    descuento = monto * 0.05
else:
    descuento = 0

total = monto - descuento
print("Descuento:", descuento)
print("Total a pagar:", total)

# %% [markdown]
# # Ejercicio 3: Acceso con usuario y clave
#
# ## Resolución guiada aplicada
#
# 1. Comprender: el sistema debe permitir el ingreso solo cuando usuario y clave sean correctos.
# 2. Entradas: `usuario` y `clave`.
# 3. Proceso: válidar usuario; si es correcto, válidar clave.
# 4. Salida y pruebas: acceso permitido o mensaje de error específico. Prueba con: `admin/1234`, `admin/0000` y `otro/1234`.
# 5. Código: recién ahora revisa o escribe la celda de Python.

# %%
usuario = input("Usuario: ")
clave = input("Clave: ")

if usuario == "admin":
    if clave == "1234":
        print("Acceso permitido")
    else:
        print("Clave incorrecta")
else:
    print("Usuario incorrecto")

# %% [markdown]
# # Ejercicio 4: Menú con `match-case`
#
# ## Problema
# Mostrar una opción de menú y responder según la opción elegida.
#
# ## Idea clave
# En Python, `match-case` funcióna como una decisión múltiple parecida al `switch` de otros lenguajes.
#
# ## Entrada
# - opción
#
# ## Proceso
# - Comparar la opción usando `match-case`.
#
# ## Salida
# - Menúaje según la opción elegida.
#
# ## Resolución guiada aplicada
#
# 1. Comprender: un menú permite elegir una acción; el programa debe responder según la opción ingresada.
# 2. Entradas: `opción` elegida por el usuario.
# 3. Proceso: usará`match-case` para dirigir cada opción a una acción.
# 4. Salida y pruebas: mensaje correspondiente o `Opción inválida`. Prueba con: `1`, `2`, `3` y `9`.
# 5. Código: recién ahora revisa o escribe la celda de Python.

# %%
print("===== Menú =====")
print("1. Saludar")
print("2. Mostrar frase")
print("3. Salir")

opción = input("Elige una opción: ")

match opción:
    case "1":
        print("Hola, futuro desarrollador")
    case "2":
        print("Programar es resolver problemás paso a paso")
    case "3":
        print("Programa finalizado")
    case _:
        print("Opción inválida")

# %% [markdown]
# ## Nota importante sobre `match-case`
#
# `match-case` está disponible desde Python 3.10. Si tu entorno usa una versión anterior, usa `if-elif-else` para resolver menús.

# %% [markdown]
# # Tarea 1: Semáforo inteligente
#
# ## Problema
# Leer un color de semáforo y mostrar la acción correspondiente.
#
# ## Restáicciones
# Usa `if-elif-else` y considera un color inválido.
#
# ## Plan antes de programar
#
# Antes de escribir código para **Semáforo inteligente**, completa:
#
# 1. Problema: explica en una frase¿qué debe resolver.
# 2. Entradas: escribe los nombres de las variables que pedirás.
# 3. Proceso: anota la fórmula, condición, bucle o estáuctura principal.
# 4. Salidas y pruebas: define los mensajes finales y dos casos de prueba.
# 5. Código: implemenúa por partes y ejecuta cada avance.

# %%
# Escribe ¿qué tu solución

# %% [markdown]
# ## Checklist de la sesión
#
# - [ ] Uso elif para varios caminos.
# - [ ] Ordeno condiciónes correctamenúe.
# - [ ] Uso anidados solo cuando ayudan.
# - [ ] Considero casos inválidos.
